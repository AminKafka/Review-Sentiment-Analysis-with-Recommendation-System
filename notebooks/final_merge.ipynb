# %% [markdown]
# # This is the final merge for all data from year 2010 to 2019 using the clean dataset of 4 source and show the charactristic of the final dataset

# %%
import pandas as pd

#merging the movie_alt (for year 2019 which I used to test the merging validity) and movie_alt1 which is a clean data for 2010 to 2018
movie_complete = pd.read_csv('/Users/Amin/Documents/GitHub/Movie_boxoffice_reviews/data/processed/movie_alt1.csv')
movie_alt = pd.read_csv('/Users/Amin/Documents/GitHub/Movie_boxoffice_reviews/data/processed/movie_alt.csv')

#drop unwanted columns
movie_alt.drop(columns=['imdb_title_id','Runtime'],inplace=True,)

#rearenge the columns for better visualization
new_col = ['Title', 'Alternative Title','director','Year' ,'date_published','Worldwide_Lifetime_Gross', 'Domestic_Lifetime_Gross', 'Foreign_Lifetime_Gross', 'tomatometer_rating', 'tomatometer_count', 'tomato_audience_rating', 'tomato_audience_vote_count', 'imdb_avg_vote', 'imdb_total_votes', 'imdb_us_voters_rating', 'imdb_us_voters_votes', 'imdb_non_us_voters_rating', 'imdb_non_us_voters_votes', 'imdb_females_avg_vote', 'imdb_females_votes', 'imdb_males_avg_vote', 'imdb_males_votes', 'Metascore']
movie_alt = movie_alt[new_col]

#concate two dataframe
movie_final = pd.concat([movie_complete,movie_alt])
movie_final.drop(columns=['Unnamed: 0'],inplace=True,)

# %%
print(movie_final.shape)
# Out:
# (3509, 23)

# %%
print(movie_final.head(5))
# Out:
#                                          Title  \
# 0                      The Mountain Between Us
# 1                                      Rampage
# 2  Valerian and the City of a Thousand Planets
# 3                                 The Forgiven
# 4                       Spider-Man: Homecoming
#
#                             Alternative Title        director  Year  \
# 0                        Il domani tra di noi  Hany Abu-Assad  2017
# 1                      Rampage: Furia animale     Brad Peyton  2018
# 2  Valerian e la citt��_��_ dei mille pianeti      Luc Besson  2017
# 3      Condannato a combattere - The Forgiven    Roland Joffթ  2017
# 4                      Spider-Man: Homecoming       Jon Watts  2017
#
#   date_published  Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 0     2017-11-23                  62832209                 30348555
# 1     2018-04-12                 428028233                101028233
# 2     2017-09-21                 225973340                 41189488
# 3     2018-03-09                     42213                        0
# 4     2017-07-06                 880166924                334201140
#
#    Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 0                32483654                  38                171  ...
# 1               327000000                  51                275  ...
# 2               184783852                  48                294  ...
# 3                   42213                  52                 23  ...
# 4               545965784                  92                390  ...
#
#    imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 0             64703                     64                  7520
# 1            137865                     61                 17163
# 2            157560                     63                 17690
# 3              1857                     59                   344
# 4            494060                     76                 57625
#
#    imdb_non_us_voters_rating  imdb_non_us_voters_votes  imdb_females_avg_vote  \
# 0                         63                     27997                     67
# 1                         60                     54731                     64
# 2                         64                     69287                     64
# 3                         58                       746                     61
# 4                         73                    172006                     76
#
#    imdb_females_votes  imdb_males_avg_vote  imdb_males_votes  Metascore
# 0               13462                   63             35093         48
# 1               13702                   60             84286         45
# 2               18118                   65             99701         51
# 3                 257                   58              1122         41
# 4               49874                   74            282567         73
#
# [5 rows x 23 columns]

# %%
print(movie_final.describe())
# Out:
#               Year  Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# count  3509.000000              3.509000e+03             3.509000e+03
# mean   2014.812197              6.983294e+07             2.699284e+07
# std       2.902111              1.868546e+08             6.780308e+07
# min    2010.000000              1.770000e+02             0.000000e+00
# 25%    2012.000000              1.882420e+05             7.714000e+03
# 50%    2015.000000              2.980982e+06             3.361660e+05
# 75%    2017.000000              4.640367e+07             2.181935e+07
# max    2019.000000              2.797501e+09             9.366622e+08
#
#        Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  \
# count            3.509000e+03         3509.000000        3509.000000
# mean             4.288294e+07           58.586777         108.740382
# std              1.240045e+08           27.942617          95.532189
# min              0.000000e+00            0.000000           1.000000
# 25%              6.245900e+04           36.000000          30.000000
# 50%              1.425098e+06           63.000000          80.000000
# 75%              2.008642e+07           83.000000         165.000000
# max              1.939128e+09          100.000000         574.000000
#
#        tomato_audience_rating  tomato_audience_vote_count  imdb_avg_vote  \
# count             3509.000000                3.509000e+03    3509.000000
# mean                56.012254                2.890696e+04      62.327729
# std                 20.365450                7.735204e+04       9.008913
# min                  0.000000                0.000000e+00      20.000000
# 25%                 41.000000                4.020000e+02      57.000000
# 50%                 56.000000                3.745000e+03      63.000000
# 75%                 72.000000                2.405200e+04      68.000000
# max                100.000000                2.374219e+06      88.000000
#
#        imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# count      3.509000e+03            3509.000000           3509.000000
# mean       6.522977e+04              62.494728           8511.039042
# std        1.319639e+05               9.084350          16124.311177
# min        1.000000e+02              15.000000              2.000000
# 25%        3.281000e+03              57.000000            507.000000
# 50%        1.464100e+04              63.000000           2194.000000
# 75%        6.579400e+04              69.000000           9162.000000
# max        2.002816e+06              94.000000         246718.000000
#
#        imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# count                3509.000000               3509.000000
# mean                   61.442861              28751.415218
# std                     9.215799              54646.400852
# min                    19.000000                 19.000000
# 25%                    56.000000               1490.000000
# 50%                    62.000000               6940.000000
# 75%                    68.000000              31126.000000
# max                    87.000000             799420.000000
#
#        imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# count            3509.000000         3509.000000          3509.000000
# mean               63.614135        10190.549444            61.730977
# std                 8.900879        19878.384900             9.186526
# min                15.000000            9.000000            20.000000
# 25%                58.000000          478.000000            56.000000
# 50%                64.000000         2420.000000            62.000000
# 75%                70.000000        10432.000000            68.000000
# max                92.000000       278964.000000            88.000000
#
#        imdb_males_votes    Metascore
# count      3.509000e+03  3509.000000
# mean       3.999704e+04    55.286406
# std        8.063227e+04    17.466723
# min        5.800000e+01     1.000000
# 25%        1.945000e+03    42.000000
# 50%        8.810000e+03    56.000000
# 75%        3.971500e+04    68.000000
# max        1.202678e+06   100.000000

# %%
movie_final.dtypes
# Out:
# Title                         object
# Alternative Title             object
# director                      object
# Year                           int64
# date_published                object
# Worldwide_Lifetime_Gross       int64
# Domestic_Lifetime_Gross        int64
# Foreign_Lifetime_Gross         int64
# tomatometer_rating             int64
# tomatometer_count              int64
# tomato_audience_rating         int64
# tomato_audience_vote_count     int64
# imdb_avg_vote                  int64
# imdb_total_votes               int64
# imdb_us_voters_rating          int64
# imdb_us_voters_votes           int64
# imdb_non_us_voters_rating      int64
# imdb_non_us_voters_votes       int64
# imdb_females_avg_vote          int64
# imdb_females_votes             int64
# imdb_males_avg_vote            int64
# imdb_males_votes               int64
# Metascore                      int64
# dtype: object

# %%
movie_final.isna().sum()
# Out:
# Title                         0
# Alternative Title             0
# director                      0
# Year                          0
# date_published                0
# Worldwide_Lifetime_Gross      0
# Domestic_Lifetime_Gross       0
# Foreign_Lifetime_Gross        0
# tomatometer_rating            0
# tomatometer_count             0
# tomato_audience_rating        0
# tomato_audience_vote_count    0
# imdb_avg_vote                 0
# imdb_total_votes              0
# imdb_us_voters_rating         0
# imdb_us_voters_votes          0
# imdb_non_us_voters_rating     0
# imdb_non_us_voters_votes      0
# imdb_females_avg_vote         0
# imdb_females_votes            0
# imdb_males_avg_vote           0
# imdb_males_votes              0
# Metascore                     0
# dtype: int64

# %%
movie_final.Title.value_counts()
# Out:
# Home                  18
# Inside Out             8
# Killers                8
# The Double             8
# Concussion             8
#                       ..
# Little                 1
# Monsoon                1
# Lady and the Tramp     1
# Nobody's Fool          1
# Blue Jay               1
# Name: Title, Length: 3294, dtype: int64

# %%
### cleaning the repeated titles
movie_final.drop([1447,1448,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464],inplace=True)
movie_final[movie_final.Title == 'Home']
# Out:
#      Title Alternative Title     director  Year date_published  \
# 1449  Home     Home - A casa  Tim Johnson  2015     2015-03-26
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1449                 386041607                177397510
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1449               208644097                  88                  8  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1449             90310                     64                 10263
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1449                         65                     36575
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1449                     71               21790                   64
#
#       imdb_males_votes  Metascore
# 1449             46093         55
#
# [1 rows x 23 columns]

# %%
movie_final.drop([857,858,859,860,862,863],inplace=True)
movie_final[movie_final.Title == 'The Double']
# Out:
#           Title      Alternative Title        director  Year date_published  \
# 856  The Double             The Double  Michael Brandt  2011     2012-03-09
# 861  The Double  Il sosia - The Double  Richard Ayoade  2013     2014-04-04
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 856                   4729855                   137921
# 861                   1662515                   200406
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 856                 4591934                  21                 52  ...
# 861                 1462109                  21                 52  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 856             28276                     60                  4522
# 861             46574                     65                  5850
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 856                         59                     15763
# 861                         65                     24700
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 856                     61                3457                   59
# 861                     66                7281                   65
#
#      imdb_males_votes  Metascore
# 856             21128         37
# 861             31096         68
#
# [2 rows x 23 columns]

# %%
movie_final.drop([418,419,420,421,423,424],inplace=True)
movie_final[movie_final.Title == 'Frozen']
# Out:
#       Title              Alternative Title                  director  Year  \
# 417  Frozen                         Frozen                Adam Green  2010
# 422  Frozen  Frozen - Il regno di ghiaccio  Chris Buck, Jennifer Lee  2013
#
#     date_published  Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 417     2011-03-25                1281508100                400953009
# 422     2013-12-19                   3843774                   246176
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 417               880555091                  63                 97  ...
# 422                 3597598                  63                 97  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 417             66334                     63                 11252
# 422            560595                     75                 72579
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 417                         61                     35798
# 422                         74                    213222
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 417                     63               11323                   61
# 422                     78              137027                   73
#
#      imdb_males_votes  Metascore
# 417             44832         43
# 422            278880         75
#
# [2 rows x 23 columns]

# %%
movie_final.drop([1518,1520,1521,1523,1524,1525],inplace=True)
movie_final[movie_final.Title == 'Concussion']
# Out:
#            Title Alternative Title         director  Year date_published  \
# 1519  Concussion        Concussion    Stacie Passon  2013     2013-12-05
# 1522  Concussion      Zona d'ombra  Peter Landesman  2015     2016-04-21
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1519                     78957                    42606
# 1522                  48623572                 34542474
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1519                   36351                  75                 59  ...
# 1522                14081098                  75                 59  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1519              4967                     57                   875
# 1522             84587                     71                 10367
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1519                         56                      1898
# 1522                         71                     36429
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1519                     59                1404                   55
# 1522                     73               10869                   71
#
#       imdb_males_votes  Metascore
# 1519              1994         56
# 1522             53597         55
#
# [2 rows x 23 columns]

# %%
movie_final.drop([841,843,844,846,847,848],inplace=True)
movie_final[movie_final.Title == 'Inside Out']
# Out:
#           Title Alternative Title                        director  Year  \
# 842  Inside Out        Inside Out                Artie Mandelberg  2011
# 845  Inside Out        Inside Out  Pete Docter, Ronnie Del Carmen  2015
#
#     date_published  Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 842     2011-09-09                      8547                        0
# 845     2015-09-16                 858848019                356921711
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 842                    8547                  98                370  ...
# 845               501926308                  98                370  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 842              1653                     49                   371
# 845            592575                     82                 63305
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 842                         43                       793
# 845                         81                    224653
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 842                     45                 112                   45
# 845                     82              102258                   82
#
#      imdb_males_votes  Metascore
# 842              1345         28
# 845            312792         94
#
# [2 rows x 23 columns]

# %%
movie_final.Title.value_counts()
# Out:
# Mother's Day    8
# Killers         8
# Victoria        6
# Gloria          4
# Paradise        4
#                ..
# Le daim         1
# O que arde      1
# El hoyo         1
# Papi Chulo      1
# Blue Jay        1
# Name: Title, Length: 3276, dtype: int64

# %%
movie_final.drop([188,189,190,191,193,194],inplace=True)
movie_final[movie_final.Title == 'Killers']
# Out:
#        Title Alternative Title                       director  Year  \
# 187  Killers           Killers                 Robert Luketic  2010
# 192  Killers           Killers  Kimo Stamboel, Timo Tjahjanto  2014
#
#     date_published  Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 187     2010-06-04                  98159963                 47059963
# 192     2014-02-01                      5248                        0
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 187                51100000                  10                108  ...
# 192                    5248                  10                108  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 187             85853                     53                 13332
# 192              4709                     64                   582
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 187                         54                     46089
# 192                         64                      2499
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 187                     57               24884                   53
# 192                     66                 383                   64
#
#      imdb_males_votes  Metascore
# 187             47920         21
# 192              3555         51
#
# [2 rows x 23 columns]

# %%
movie_final.drop([2121,2122,2123,2125],inplace=True)
movie_final[movie_final.Title == 'Victoria']
# Out:
#          Title             Alternative Title            director  Year  \
# 2120  Victoria                      Victoria  Sebastian Schipper  2015
# 2124  Victoria  Tutti gli uomini di Victoria       Justine Triet  2016
#
#      date_published  Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 2120     2017-03-23                   4971428                        0
# 2124     2018-01-25                   3192275                        0
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 2120                 4971428                  82                134  ...
# 2124                 3192275                  82                134  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 2120             50906                     75                  3385
# 2124              2876                     63                   115
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 2120                         76                     28235
# 2124                         62                      1779
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 2120                     76                6736                   76
# 2124                     63                 530                   62
#
#       imdb_males_votes  Metascore
# 2120             33357         77
# 2124              1750         58
#
# [2 rows x 23 columns]

# %%
movie_final.drop([1434,1435,1436],inplace=True)
movie_final[movie_final.Title == 'The Other Woman']
# Out:
#                 Title Alternative Title         director  Year date_published  \
# 1433  The Other Woman  Tutte contro lui  Nick Cassavetes  2014     2014-06-19
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1433                 196710396                 83911193
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1433               112799203                  39                 46  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1433            129001                     60                 15455
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1433                         59                     56805
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1433                     65               45008                   57
#
#       imdb_males_votes  Metascore
# 1433             56547         39
#
# [1 rows x 23 columns]

# %%
movie_final.drop([880,881,883],inplace=True)
movie_final[movie_final.Title == 'Stolen']
# Out:
#       Title Alternative Title    director  Year date_published  \
# 882  Stolen            Stolen  Simon West  2012     2012-09-06
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 882                  17415418                   304318
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 882                17111100                  20                 20  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 882             42715                     54                  4736
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 882                         55                     23413
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 882                     57                3759                   55
#
#      imdb_males_votes  Metascore
# 882             32856         43
#
# [1 rows x 23 columns]

# %%
movie_final.Title.value_counts()
# Out:
# Mother's Day       8
# Eden               4
# Little Women       4
# The Boy            4
# Intruders          4
#                   ..
# Vitalina Varela    1
# Rosie              1
# Girl               1
# The Glass Room     1
# Blue Jay           1
# Name: Title, Length: 3267, dtype: int64

# %%
movie_final.drop([1007,1008,1009],inplace=True)
movie_final[movie_final.Title == 'Eden']
# Out:
#      Title Alternative Title         director  Year date_published  \
# 1006  Eden   Urla silenziose  Megan Griffiths  2012     2013-07-19
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1006                    507914                    65460
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1006                  442454                  85                 40  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1006              8181                     68                  1373
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1006                         65                      4234
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1006                     70                1964                   65
#
#       imdb_males_votes  Metascore
# 1006              4914         63
#
# [1 rows x 23 columns]

# %%
movie_final.drop([337,338],inplace=True)
movie_final[movie_final.Title == 'Paradise']
# Out:
#         Title               Alternative Title              director  Year  \
# 336  Paradise  Paradise - Viaggio a Las Vegas           Diablo Cody  2013
# 339  Paradise                        Paradise  Andrey Konchalovskiy  2016
#
#     date_published  Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 336     2013-10-18                     84108                        0
# 339     2018-01-25                     19565                        0
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 336                   84108                  22                 41  ...
# 339                   19565                  22                 41  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 336              3387                     51                   846
# 339              1545                     70                   117
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 336                         48                      1447
# 339                         70                       895
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 336                     53                1139                   48
# 339                     74                 260                   69
#
#      imdb_males_votes  Metascore
# 336              1721         35
# 339               964         52
#
# [2 rows x 23 columns]

# %%
movie_final.drop([1824,1825,1826],inplace=True)
movie_final[movie_final.Title == 'Extraterrestrial']
# Out:
#                  Title Alternative Title       director  Year date_published  \
# 1823  Extraterrestrial  Extraterrestrial  Colin Minihan  2014     2014-10-17
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1823                    266512                        0
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1823                  266512                  69                 29  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1823             14530                     52                  2493
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1823                         49                      7048
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1823                     50                1695                   50
#
#       imdb_males_votes  Metascore
# 1823             10441         38
#
# [1 rows x 23 columns]

# %%
movie_final.drop([1642,1643,1644],inplace=True)
movie_final[movie_final.Title == 'Gloria']
# Out:
#        Title Alternative Title         director  Year date_published  \
# 1641  Gloria            Gloria  Sebastián Lelio  2013     2013-10-10
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1641                   6461559                  2107925
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1641                 4353634                  99                128  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1641              8262                     67                  1008
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1641                         68                      4985
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1641                     68                1727                   68
#
#       imdb_males_votes  Metascore
# 1641              5313         83
#
# [1 rows x 23 columns]

# %%
movie_final.drop([95,807],inplace=True)
movie_final[movie_final.Title == 'Little Women']
# Out:
#             Title Alternative Title           director  Year date_published  \
# 94   Little Women     Piccole donne       Greta Gerwig  2019     2020-01-09
# 808  Little Women      Little Women  Clare Niederpruem  2018     2018-09-28
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 94                  216601214                108101214
# 808                  12165890                  1379497
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 94                108500000                  30                 27  ...
# 808                10786393                  30                 27  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 94             122387                     80                 16089
# 808              1070                     52                   287
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 94                          77                     43050
# 808                         49                       268
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 94                      80               28052                   77
# 808                     55                 366                   47
#
#      imdb_males_votes  Metascore
# 94              51849         91
# 808               350         40
#
# [2 rows x 23 columns]

# %%
movie_final.drop([829,830,831],inplace=True)
movie_final[movie_final.Title == 'Intruders']
# Out:
#          Title Alternative Title                 director  Year  \
# 828  Intruders         Intruders  Juan Carlos Fresnadillo  2011
#
#     date_published  Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 828     2011-10-07                   5486559                    69136
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 828                 5417423                  32                 73  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 828             19933                     54                  2908
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 828                         54                     11841
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 828                     55                3619                   54
#
#      imdb_males_votes  Metascore
# 828             14117         45
#
# [1 rows x 23 columns]

# %%
movie_final.Title.value_counts()
# Out:
# Mother's Day    8
# Anna            4
# The Boy         4
# The Reunion     3
# Brotherhood     3
#                ..
# Se rokh         1
# Donbass         1
# Rafiki          1
# Away            1
# Blue Jay        1
# Name: Title, Length: 3257, dtype: int64

# %%
movie_final.drop([1651,1652,1654],inplace=True)
movie_final[movie_final.Title == 'The Boy']
# Out:
#         Title Alternative Title            director  Year date_published  \
# 1653  The Boy           The Boy  William Brent Bell  2016     2016-05-12
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1653                  73929392                 35819556
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1653                38109836                  30                 61  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1653             77485                     60                  9829
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1653                         59                     31501
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1653                     62               15908                   59
#
#       imdb_males_votes  Metascore
# 1653             40841         42
#
# [1 rows x 23 columns]

# %%
movie_final.drop([986,987],inplace=True)
movie_final[movie_final.Title == 'Anna']
# Out:
#      Title Alternative Title      director  Year date_published  \
# 1038  Anna              Anna    Luc Besson  2019     2019-06-21
# 985   Anna              Anna  Jorge Dorado  2013     2014-01-24
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1038                  31626978                  7743794
# 985                    1257142                     4288
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1038                23883184                  33                 69  ...
# 985                  1252854                  33                 21  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1038             55206                     66                  5827
# 985              21130                     63                  2403
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1038                         65                     24252
# 985                          64                     11053
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1038                     68                5759                   66
# 985                      66                4772                   64
#
#       imdb_males_votes  Metascore
# 1038             34286         40
# 985              12584         42
#
# [2 rows x 23 columns]

# %%
movie_final.drop([1413],inplace=True)
movie_final[movie_final.Title == 'Barbara']
# Out:
#         Title     Alternative Title           director  Year date_published  \
# 777   Barbara               Barbara    Mathieu Amalric  2017     2017-09-06
# 1412  Barbara  La scelta di Barbara  Christian Petzold  2012     2013-03-14
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 777                    2929455                        0
# 1412                   6908277                  1013902
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 777                  2929455                  84                 19  ...
# 1412                 5894375                  94                 79  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 777                949                     60                    64
# 1412             12403                     73                  1461
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 777                          61                       597
# 1412                         71                      7660
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 777                      64                 157                   60
# 1412                     72                2326                   71
#
#       imdb_males_votes  Metascore
# 777                616         68
# 1412              8197         86
#
# [2 rows x 23 columns]

# %%
movie_final.drop([438,349],inplace=True)
movie_final[movie_final.Title == 'Brotherhood']
# Out:
#            Title Alternative Title    director  Year date_published  \
# 347  Brotherhood       Brotherhood  Will Canon  2010     2010-11-18
# 348  Brotherhood       Brotherhood  Will Canon  2010     2010-11-18
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 347                   4613846                        0
# 348                    240887                     8979
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 347                 4613846                  54                 26  ...
# 348                  231908                  54                 26  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 347              3861                     65                   952
# 348              3861                     65                   952
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 347                         63                      2050
# 348                         63                      2050
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 347                     67                 441                   63
# 348                     67                 441                   63
#
#      imdb_males_votes  Metascore
# 347              3000         52
# 348              3000         52
#
# [2 rows x 23 columns]

# %%
movie_final.Title.value_counts()
# Out:
# Mother's Day      8
# The King          3
# The Reunion       3
# Weekend           3
# Lucky             3
#                  ..
# Rafiki            1
# Away              1
# Gongjak           1
# Dolor y gloria    1
# Blue Jay          1
# Name: Title, Length: 3252, dtype: int64

# %%
movie_final.drop([1843,1844],inplace=True)
movie_final[movie_final.Title == 'The Guest']
# Out:
#           Title Alternative Title      director  Year date_published  \
# 1842  The Guest         The Guest  Adam Wingard  2014     2014-09-05
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1842                   2700051                   332890
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1842                 2367161                  91                115  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1842             88843                     70                 12699
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1842                         66                     42392
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1842                     64               11151                   67
#
#       imdb_males_votes  Metascore
# 1842             60430         76
#
# [1 rows x 23 columns]

# %%
movie_final.drop(605,inplace=True)
movie_final[movie_final.Title == 'Lucky']
# Out:
#      Title Alternative Title            director  Year date_published  \
# 591  Lucky             Lucky  John Carroll Lynch  2017     2018-08-29
# 606  Lucky             Lucky       Gil Cates Jr.  2011     2011-07-15
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 591                   2728446                   955925
# 606                      8564                     8564
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 591                 1772521                  97                151  ...
# 606                       0                  23                 13  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 591             18230                     73                  2001
# 606              3486                     57                  1134
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 591                         73                      9520
# 606                         51                      1586
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 591                     75                2001                   73
# 606                     57                 688                   53
#
#      imdb_males_votes  Metascore
# 591             12172         80
# 606              2460         41
#
# [2 rows x 23 columns]

# %%
movie_final.drop(1916,inplace=True)
movie_final[movie_final.Title == 'Blackbird']
# Out:
#           Title Alternative Title         director  Year date_published  \
# 1226  Blackbird         Blackbird    Roger Michell  2019     2020-09-18
# 1917  Blackbird         Blackbird  Patrik-Ian Polk  2014     2015-07-28
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1226                   1700296                  1700296
# 1917                     78400                    78400
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1226                       0                  63                103  ...
# 1917                       0                  40                 10  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1226               187                     54                    27
# 1917               972                     55                   293
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1226                         70                        88
# 1917                         52                       304
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1226                     81                  28                   65
# 1917                     54                 188                   54
#
#       imdb_males_votes  Metascore
# 1226               103         53
# 1917               584         33
#
# [2 rows x 23 columns]

# %%
movie_final.drop([979,980],inplace=True)
movie_final[movie_final.Title == 'Weekend']
# Out:
#        Title Alternative Title      director  Year date_published  \
# 978  Weekend           Weekend  Andrew Haigh  2011     2016-03-10
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 978                   4689925                        0
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 978                 4689925                  95                 85  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 978             27499                     78                  3930
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 978                         76                     13540
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 978                     76                5524                   76
#
#      imdb_males_votes  Metascore
# 978             16556         81
#
# [1 rows x 23 columns]

# %%
movie_final.Title.value_counts()
# Out:
# Mother's Day      8
# The Reunion       3
# Boy Meets Girl    3
# Aftermath         3
# Escape Room       3
#                  ..
# Gongjak           1
# Dolor y gloria    1
# The Wretched      1
# Sauvage           1
# Blue Jay          1
# Name: Title, Length: 3249, dtype: int64

# %%
movie_final.drop([956,957],inplace=True)
movie_final[movie_final.Title == 'The Hunter']
# Out:
#           Title Alternative Title         director  Year date_published  \
# 955  The Hunter        The Hunter  Daniel Nettheim  2011     2011-10-06
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 955                   1680778                   176669
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 955                 1504109                  72                 95  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 955             36257                     68                  5750
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 955                         67                     20817
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 955                     67                2508                   67
#
#      imdb_males_votes  Metascore
# 955             28911         63
#
# [1 rows x 23 columns]

# %%
movie_final.drop([1850,1851],inplace=True)
movie_final[movie_final.Title == 'Boy Meets Girl']
# Out:
#                Title Alternative Title        director  Year date_published  \
# 1849  Boy Meets Girl    Boy Meets Girl  Eric Schaeffer  2014     2015-02-06
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1849                     20441                    20441
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1849                       0                  88                 17  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1849              4152                     73                   864
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1849                         69                      1626
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1849                     74                1534                   68
#
#       imdb_males_votes  Metascore
# 1849              1708         68
#
# [1 rows x 23 columns]

# %%
movie_final.drop(727,inplace=True)
movie_final[movie_final.Title == 'Aftermath']
# Out:
#          Title        Alternative Title        director  Year date_published  \
# 263  Aftermath  Aftermath - La vendetta  Elliott Lester  2017     2017-04-07
# 726  Aftermath                Aftermath    Péter Engert  2014     2015-03-27
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 263                    840809                        0
# 726                   1696330                        0
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 263                  840809                  42                 55  ...
# 726                 1696330                  47                 17  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 263             21375                     57                  2334
# 726              1697                     49                   421
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 263                         56                     10585
# 726                         46                       745
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 263                     57                1610                   57
# 726                     46                 267                   47
#
#      imdb_males_votes  Metascore
# 263             15133         44
# 726              1134         40
#
# [2 rows x 23 columns]

# %%
movie_final.drop([603,604],inplace=True)
movie_final[movie_final.Title == 'Escape Room']
# Out:
#            Title Alternative Title      director  Year date_published  \
# 602  Escape Room       Escape Room  Adam Robitel  2019     2019-03-14
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 602                 155712077                 57005601
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 602                98706476                  51                157  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 602             77941                     63                  8452
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 602                         63                     32119
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 602                     66               10330                   63
#
#      imdb_males_votes  Metascore
# 602             44695         48
#
# [1 rows x 23 columns]

# %%
movie_final.Title.value_counts()
# Out:
# Mother's Day      8
# The King          3
# The Reunion       3
# Ma                2
# Chef              2
#                  ..
# Gongjak           1
# Dolor y gloria    1
# The Wretched      1
# Sauvage           1
# Blue Jay          1
# Name: Title, Length: 3245, dtype: int64

# %%
movie_final.drop([1081,1082],inplace=True)
movie_final[movie_final.Title == 'The Reunion']
# Out:
#             Title Alternative Title        director  Year date_published  \
# 1080  The Reunion       The Reunion  Michael Pavone  2011     2012-02-02
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1080                   6820097                        0
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1080                 6820097                   8                 12  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1080              3782                     54                   768
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1080                         49                      1782
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1080                     58                 433                   51
#
#       imdb_males_votes  Metascore
# 1080              2834         26
#
# [1 rows x 23 columns]

# %%
movie_final.drop([1130,1131],inplace=True)
movie_final[movie_final.Title == 'The King']
# Out:
#          Title Alternative Title       director  Year date_published  \
# 1129  The King             Il re  David Mich��d  2019     2019-11-01
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1129                  37886707                        0
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1129                37886707                  71                141  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1129             79237                     73                  7581
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1129                         72                     31294
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1129                     72                9387                   72
#
#       imdb_males_votes  Metascore
# 1129             44254         62
#
# [1 rows x 23 columns]

# %%
movie_final.drop(23,inplace=True)
movie_final[movie_final.Title == 'Coco']
# Out:
#    Title Alternative Title                    director  Year date_published  \
# 22  Coco              Coco  Lee Unkrich, Adrian Molina  2017     2017-12-28
#
#     Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  Foreign_Lifetime_Gross  \
# 22                 807817888                210460015               597357873
#
#     tomatometer_rating  tomatometer_count  ...  imdb_total_votes  \
# 22                  97                342  ...            352455
#
#     imdb_us_voters_rating  imdb_us_voters_votes  imdb_non_us_voters_rating  \
# 22                     84                 39505                         83
#
#     imdb_non_us_voters_votes  imdb_females_avg_vote  imdb_females_votes  \
# 22                    126988                     86               55906
#
#     imdb_males_avg_vote  imdb_males_votes  Metascore
# 22                   83            182066         81
#
# [1 rows x 23 columns]

# %%
movie_final.drop(710,inplace=True)
movie_final[movie_final.Title == 'Outcast']
# Out:
#        Title            Alternative Title     director  Year date_published  \
# 709  Outcast  Outcast - L'ultimo templare  Nick Powell  2014     2015-04-03
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 709                   5148503                        0
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 709                 5148503                   5                 22  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 709             12210                     46                  1570
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 709                         46                      5806
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 709                     51                1221                   46
#
#      imdb_males_votes  Metascore
# 709              8693         33
#
# [1 rows x 23 columns]

# %%
movie_final.Title.value_counts()
# Out:
# Mother's Day      8
# Phantom           2
# The Nun           2
# ATM               2
# The Debt          2
#                  ..
# Gongjak           1
# Dolor y gloria    1
# The Wretched      1
# Sauvage           1
# Blue Jay          1
# Name: Title, Length: 3239, dtype: int64

# %%
movie_final.drop(1535,inplace=True)
movie_final[movie_final.Title == 'Wild']
# Out:
#      Title Alternative Title          director  Year date_published  \
# 1534  Wild              Wild  Jean-Marc Vallée  2014     2015-03-05
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1534                  52501541                 37880356
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1534                14621185                  88                272  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1534            117835                     72                 15444
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1534                         71                     56976
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1534                     74               28456                   71
#
#       imdb_males_votes  Metascore
# 1534             66468         74
#
# [1 rows x 23 columns]

# %%
movie_final.drop(996,inplace=True)
movie_final[movie_final.Title == 'Innocence']
# Out:
#          Title Alternative Title         director  Year date_published  \
# 995  Innocence         Innocence  Hilary Brougher  2013     2016-01-11
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 995                   1102022                        0
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 995                 1102022                  19                 26  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 995              1157                     47                   321
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 995                         43                       449
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 995                     48                 363                   44
#
#      imdb_males_votes  Metascore
# 995               591         26
#
# [1 rows x 23 columns]

# %%
movie_final.drop(930,inplace=True)
movie_final[movie_final.Title == 'Creature']
# Out:
#         Title Alternative Title      director  Year date_published  \
# 929  Creature          Creature  Fred Andrews  2011     2011-09-09
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 929                    533235                   508714
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 929                   24521                  10                 29  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 929              2774                     39                  1090
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 929                         34                      1064
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 929                     36                 300                   36
#
#      imdb_males_votes  Metascore
# 929              2193         31
#
# [1 rows x 23 columns]

# %%
movie_final.drop(1023,inplace=True)
movie_final[movie_final.Title == 'Dog Days']
# Out:
#          Title Alternative Title    director  Year date_published  \
# 1022  Dog Days          Dog Days  Ken Marino  2018     2018-09-13
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1022                   6842356                  6809080
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1022                   33276                  63                 67  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1022              3926                     62                   740
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1022                         60                      1348
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1022                     66                1124                   59
#
#       imdb_males_votes  Metascore
# 1022              1605         47
#
# [1 rows x 23 columns]

# %%
movie_final.Title.value_counts()
# Out:
# Mother's Day      8
# Ma                2
# Reality           2
# Miss Bala         2
# Legendary         2
#                  ..
# Gongjak           1
# Dolor y gloria    1
# The Wretched      1
# Sauvage           1
# Blue Jay          1
# Name: Title, Length: 3236, dtype: int64

# %%
movie_final.drop(876,inplace=True)
movie_final[movie_final.Title == 'Night School']
# Out:
#             Title Alternative Title        director  Year date_published  \
# 875  Night School  La scuola serale  Malcolm D. Lee  2018     2018-11-08
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 875                 103105878                 77339130
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 875                25766748                  26                140  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 875             32865                     56                  5394
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 875                         55                     11247
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 875                     58                4700                   55
#
#      imdb_males_votes  Metascore
# 875             18344         43
#
# [1 rows x 23 columns]

# %%
movie_final.drop(521,inplace=True)
movie_final[movie_final.Title == 'Euphoria']
# Out:
#         Title Alternative Title       director  Year date_published  \
# 520  Euphoria          Euphoria  Lisa Langseth  2017     2018-02-02
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 520                   1949722                        0
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 520                 1949722                  19                 26  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 520              3357                     56                   250
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 520                         57                      1818
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 520                     61                 775                   56
#
#      imdb_males_votes  Metascore
# 520              1823         32
#
# [1 rows x 23 columns]

# %%
movie_final.drop(654,inplace=True)
movie_final[movie_final.Title == 'Anonymous']
# Out:
#          Title Alternative Title         director  Year date_published  \
# 653  Anonymous         Anonymous  Roland Emmerich  2011     2011-11-18
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 653                  15395087                  4463292
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 653                10931795                  45                175  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 653             38937                     68                  5610
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 653                         69                     22613
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 653                     71                8712                   68
#
#      imdb_males_votes  Metascore
# 653             25615         50
#
# [1 rows x 23 columns]

# %%
movie_final.Title.value_counts()
# Out:
# Mother's Day      8
# Stone             2
# The Last Ride     2
# Reality           2
# Legendary         2
#                  ..
# Away              1
# Gongjak           1
# Dolor y gloria    1
# The Wretched      1
# Blue Jay          1
# Name: Title, Length: 3233, dtype: int64

# %%
movie_final.drop(1022,inplace=True)
movie_final[movie_final.Title == 'Blood Ties']
# Out:
#            Title                 Alternative Title         director  Year  \
# 1021  Blood Ties  Blood Ties - La legge del sangue  Guillaume Canet  2013
#
#      date_published  Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1021     2013-10-30                   2566435                    42472
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1021                 2523963                  52                 56  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1021             18721                     64                  2470
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1021                         65                     10461
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1021                     64                2125                   65
#
#       imdb_males_votes  Metascore
# 1021             13699         45
#
# [1 rows x 23 columns]

# %%
movie_final.drop(500,inplace=True)
movie_final[movie_final.Title == 'The Hero']
# Out:
#         Title Alternative Title     director  Year date_published  \
# 499  The Hero          The Hero  Brett Haley  2017     2017-06-09
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 499                   4101699                  4077333
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 499                   24366                  78                113  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 499              7828                     67                  1912
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 499                         64                      2999
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 499                     64                1003                   65
#
#      imdb_males_votes  Metascore
# 499              5083         61
#
# [1 rows x 23 columns]

# %%
movie_final.Title.value_counts()
# Out:
# Mother's Day      8
# Rush              2
# Reality           2
# Paranoia          2
# Legendary         2
#                  ..
# Rafiki            1
# Away              1
# Gongjak           1
# Dolor y gloria    1
# Blue Jay          1
# Name: Title, Length: 3231, dtype: int64

# %%
movie_final.drop(1941,inplace=True)
movie_final[movie_final.Title == 'Captive']
# Out:
#         Title Alternative Title       director  Year date_published  \
# 1940  Captive           Captive  Jerry Jameson  2015     2015-09-18
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1940                   2801508                  2583301
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1940                  218207                  27                 52  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1940              6360                     56                  1014
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1940                         52                      3013
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1940                     56                 994                   53
#
#       imdb_males_votes  Metascore
# 1940              4138         36
#
# [1 rows x 23 columns]

# %%
movie_final.Title.value_counts()
# Out:
# Mother's Day            8
# The Art of the Steal    2
# The Silence             2
# Elena                   2
# The Debt                2
#                        ..
# Rafiki                  1
# Away                    1
# Gongjak                 1
# Dolor y gloria          1
# Blue Jay                1
# Name: Title, Length: 3231, dtype: int64

# %%
movie_final.drop(712,inplace=True)
movie_final[movie_final.Title == 'A Better Life']
# Out:
#              Title      Alternative Title     director  Year date_published  \
# 711  A Better Life  Per una vita migliore  Chris Weitz  2011     2011-07-28
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 711                   4024643                        0
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 711                 4024643                  85                107  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 711             15112                     73                  3195
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 711                         71                      8272
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 711                     74                2491                   72
#
#      imdb_males_votes  Metascore
# 711             10988         64
#
# [1 rows x 23 columns]

# %%
movie_final.drop(735,inplace=True)
movie_final[movie_final.Title == 'War Horse']
# Out:
#          Title Alternative Title          director  Year date_published  \
# 734  War Horse         War Horse  Steven Spielberg  2011     2012-02-17
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 734                 177584879                 79884879
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 734                97700000                  75                237  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 734            144320                     72                 20792
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 734                         72                     73279
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 734                     76               26159                   72
#
#      imdb_males_votes  Metascore
# 734             93768         72
#
# [1 rows x 23 columns]

# %%
movie_final.drop(576,inplace=True)
movie_final[movie_final.Title == 'The Kitchen']
# Out:
#            Title      Alternative Title        director  Year date_published  \
# 575  The Kitchen  Le regine del crimine  Andrea Berloff  2019     2019-08-09
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 575                  15980032                 12180032
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 575                 3800000                  24                225  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 575             13851                     55                  2982
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 575                         54                      4542
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 575                     60                2695                   53
#
#      imdb_males_votes  Metascore
# 575              7165         35
#
# [1 rows x 23 columns]

# %%
movie_final.Title.value_counts()
# Out:
# Mother's Day      8
# Pilgrimage        2
# Aurora            2
# Reality           2
# Blackbird         2
#                  ..
# Away              1
# Gongjak           1
# Dolor y gloria    1
# The Wretched      1
# Blue Jay          1
# Name: Title, Length: 3228, dtype: int64

# %%
movie_final.drop(165,inplace=True)
movie_final[movie_final.Title == 'Parental Guidance']
# Out:
#                  Title  Alternative Title      director  Year date_published  \
# 164  Parental Guidance  Parental Guidance  Andy Fickman  2012     2013-07-11
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 164                 119772232                 77267296
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 164                42504936                  18                 93  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 164             24582                     60                  5414
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 164                         59                      9881
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 164                     65                6381                   59
#
#      imdb_males_votes  Metascore
# 164             13767         36
#
# [1 rows x 23 columns]

# %%
movie_final.drop(1500,inplace=True)
movie_final[movie_final.Title == 'A Perfect Man']
# Out:
#               Title Alternative Title          director  Year date_published  \
# 1499  A Perfect Man     A Perfect Man  Kees Van Oostrum  2013     2013-10-31
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1499                   4208906                        0
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1499                 4208906                  20                  5  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1499              1931                     52                   458
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1499                         52                       858
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1499                     53                 739                   51
#
#       imdb_males_votes  Metascore
# 1499               900         31
#
# [1 rows x 23 columns]

# %%
movie_final.Title.value_counts()
# Out:
# Mother's Day      8
# Ma                2
# Daylight          2
# Ghoul             2
# Blackbird         2
#                  ..
# Gongjak           1
# Dolor y gloria    1
# The Wretched      1
# Sauvage           1
# Blue Jay          1
# Name: Title, Length: 3227, dtype: int64

# %%
movie_final.drop(1002,inplace=True)
movie_final[movie_final.Title == 'The Silence']
# Out:
#             Title Alternative Title          director  Year date_published  \
# 1003  The Silence       The Silence  John R. Leonetti  2019     2019-04-10
#
#       Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 1003                      5936                        0
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 1003                    5936                  30                 33  ...
#
#       imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 1003             35091                     53                  3864
#
#       imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 1003                         52                     14383
#
#       imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 1003                     54                5370                   52
#
#       imdb_males_votes  Metascore
# 1003             19555         25
#
# [1 rows x 23 columns]

# %%
movie_final.drop([554,555,556],inplace=True)
movie_final[movie_final.director=='Garry Marshall']
# Out:
#                Title         Alternative Title        director  Year  \
# 84   Valentine's Day  Appuntamento con l'amore  Garry Marshall  2010
# 553     Mother's Day              Mother's Day  Garry Marshall  2016
# 775   New Year's Eve      Capodanno a New York  Garry Marshall  2011
#
#     date_published  Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 84      2010-03-12                 216485654                110485654
# 553     2016-06-23                  48782670                 32492859
# 775     2011-12-23                 142044638                 54544638
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 84                106000000                  18                190  ...
# 553                16289811                  41                 44  ...
# 775                87500000                   7                141  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 84             112228                     56                 18831
# 553             32022                     55                  3543
# 775             80243                     53                 10620
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 84                          57                     56745
# 553                         56                     13882
# 775                         56                     39914
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 84                      59               44533                   56
# 553                     59               11850                   54
# 775                     60               32368                   54
#
#      imdb_males_votes  Metascore
# 84              48765         34
# 553             11884         18
# 775             34096         22
#
# [3 rows x 23 columns]

# %%
movie_final.drop([549,551,552],inplace=True)
movie_final[movie_final.director=='Darren Lynn Bousman']
# Out:
#             Title Alternative Title             director  Year date_published  \
# 699    St. Agatha        St. Agatha  Darren Lynn Bousman  2018     2019-02-08
# 550  Mother's Day      Mother's Day  Darren Lynn Bousman  2010     2011-05-05
# 613      Abattoir          Abattoir  Darren Lynn Bousman  2016     2016-12-09
#
#      Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 699                   1468454                        0
# 550                    863044                        0
# 613                    663460                        0
#
#      Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 699                 1468454                  64                 25  ...
# 550                  863044                  41                 44  ...
# 613                  663460                  38                 21  ...
#
#      imdb_total_votes  imdb_us_voters_rating  imdb_us_voters_votes  \
# 699              4769                     52                   830
# 550             15694                     63                  2919
# 613              3687                     47                   881
#
#      imdb_non_us_voters_rating  imdb_non_us_voters_votes  \
# 699                         48                      1484
# 550                         62                      8397
# 613                         43                      1490
#
#      imdb_females_avg_vote  imdb_females_votes  imdb_males_avg_vote  \
# 699                     50                 857                   48
# 550                     64                3061                   62
# 613                     44                 736                   44
#
#      imdb_males_votes  Metascore
# 699              2042         63
# 550             10622         34
# 613              2209         40
#
# [3 rows x 23 columns]

# %%
movie_final.Title.value_counts()
# Out:
# The Debt                               2
# Stone                                  2
# Anna                                   2
# The Call                               2
# Leap Year                              2
#                                       ..
# Sauvage                                1
# Divino Amor                            1
# Nancy Drew and the Hidden Staircase    1
# The Golem                              1
# Blue Jay                               1
# Name: Title, Length: 3221, dtype: int64

# %%
#save the final data set and print the charactristic of the set
movie_final.to_csv('/Users/Amin/Documents/GitHub/Movie_boxoffice_reviews/data/processed/movie_db_fianl1.csv')
movie_final.columns
# Out:
# Index(['Title', 'Alternative Title', 'director', 'Year', 'date_published',
#        'Worldwide_Lifetime_Gross', 'Domestic_Lifetime_Gross',
#        'Foreign_Lifetime_Gross', 'tomatometer_rating', 'tomatometer_count',
#        'tomato_audience_rating', 'tomato_audience_vote_count', 'imdb_avg_vote',
#        'imdb_total_votes', 'imdb_us_voters_rating', 'imdb_us_voters_votes',
#        'imdb_non_us_voters_rating', 'imdb_non_us_voters_votes',
#        'imdb_females_avg_vote', 'imdb_females_votes', 'imdb_males_avg_vote',
#        'imdb_males_votes', 'Metascore'],
#       dtype='object')

# %%
df = pd.read_csv('/Users/Amin/Desktop/mojo.csv')
df.columns
movie_2022  = movie_final.merge(df,left_on='Title',right_on='Title',how='left')

# %%
movie_2022.shape
# Out:
# (3400, 30)

# %%
movie_2022
# Out:
#                                             Title  \
# 0                         The Mountain Between Us
# 1                                         Rampage
# 2     Valerian and the City of a Thousand Planets
# 3                                    The Forgiven
# 4                          Spider-Man: Homecoming
# ...                                           ...
# 3395                                     The Land
# 3396                        The Eyes of My Mother
# 3397                                     Paterson
# 3398                Kingsglaive: Final Fantasy XV
# 3399                                     Blue Jay
#
#                                Alternative Title          director  Year_x  \
# 0                           Il domani tra di noi    Hany Abu-Assad    2017
# 1                         Rampage: Furia animale       Brad Peyton    2018
# 2     Valerian e la citt��_��_ dei mille pianeti        Luc Besson    2017
# 3         Condannato a combattere - The Forgiven      Roland Joffթ    2017
# 4                         Spider-Man: Homecoming         Jon Watts    2017
# ...                                          ...               ...     ...
# 3395                                    The Land  Steven Caple Jr.    2016
# 3396                       The Eyes of My Mother     Nicolas Pesce    2016
# 3397                                    Paterson      Jim Jarmusch    2016
# 3398               Kingsglaive: Final Fantasy XV     Takeshi Nozue    2016
# 3399                                    Blue Jay      Alex Lehmann    2016
#
#      date_published  Worldwide_Lifetime_Gross  Domestic_Lifetime_Gross  \
# 0        2017-11-23                  62832209                 30348555
# 1        2018-04-12                 428028233                101028233
# 2        2017-09-21                 225973340                 41189488
# 3        2018-03-09                     42213                        0
# 4        2017-07-06                 880166924                334201140
# ...             ...                       ...                      ...
# 3395     2016-08-04                     43756                    43756
# 3396     2016-12-02                     29539                    27099
# 3397     2016-12-29                   9588282                  2152738
# 3398     2016-07-09                   5725482                   269980
# 3399     2016-12-06                     21626                    21626
#
#       Foreign_Lifetime_Gross  tomatometer_rating  tomatometer_count  ...  \
# 0                   32483654                  38                171  ...
# 1                  327000000                  51                275  ...
# 2                  184783852                  48                294  ...
# 3                      42213                  52                 23  ...
# 4                  545965784                  92                390  ...
# ...                      ...                 ...                ...  ...
# 3395                       0                  70                 20  ...
# 3396                    2440                  78                 99  ...
# 3397                 7435544                  96                258  ...
# 3398                 5455502                  12                 17  ...
# 3399                       0                  91                 32  ...
#
#       imdb_males_avg_vote  imdb_males_votes  Metascore  Unnamed: 0   index  \
# 0                      63             35093         48      4568.0  2394.0
# 1                      60             84286         45      5220.0  3046.0
# 2                      65             99701         51      4543.0  2369.0
# 3                      58              1122         41      5244.0  3070.0
# 4                      74            282567         73      4272.0  2098.0
# ...                   ...               ...        ...         ...     ...
# 3395                   63              1037         50      3929.0  1755.0
# 3396                   62              7011         63      3787.0  1613.0
# 3397                   74             39370         90      3483.0  1309.0
# 3398                   68             13868         35      4030.0  1856.0
# 3399                   73              6544         69      3696.0  1522.0
#
#       Year_y  mc_av  mc_no  ma_av   ma_no
# 0     2017.0   48.0   37.0   51.0   107.0
# 1     2018.0   45.0   46.0   57.0   291.0
# 2     2017.0   51.0   45.0   64.0   637.0
# 3     2018.0   41.0    9.0   63.0     6.0
# 4     2017.0   73.0   51.0   75.0  2310.0
# ...      ...    ...    ...    ...     ...
# 3395  2016.0   50.0   10.0   50.0    10.0
# 3396  2016.0   63.0   23.0   60.0    28.0
# 3397  2016.0   90.0   42.0   79.0   208.0
# 3398  2016.0   35.0   10.0   84.0   614.0
# 3399  2016.0   69.0   16.0   79.0    34.0
#
# [3400 rows x 30 columns]

# %%
movie_2022.to_csv('/Users/Amin/Desktop/temp.csv')

# %%
db_fix = pd.read_csv('/Users/Amin/Documents/GitHub/Movie_boxoffice_reviews/data/interim/movie_db_fix.csv',encoding = "ISO-8859-1", engine='python')

# %%
db_fix.drop(columns=['Unnamed: 0','Metascore','Unnamed: 0.1','index','Year_y'],inplace=True)

# %%
db_fix.dropna(inplace=True)

# %%
db_fix.isna().sum()
# Out:
# Title                         0
# Alternative Title             0
# director                      0
# Year_x                        0
# date_published                0
# Worldwide_Lifetime_Gross      0
# Domestic_Lifetime_Gross       0
# Foreign_Lifetime_Gross        0
# tomatometer_rating            0
# tomatometer_count             0
# tomato_audience_rating        0
# tomato_audience_vote_count    0
# imdb_avg_vote                 0
# imdb_total_votes              0
# imdb_us_voters_rating         0
# imdb_us_voters_votes          0
# imdb_non_us_voters_rating     0
# imdb_non_us_voters_votes      0
# imdb_females_avg_vote         0
# imdb_females_votes            0
# imdb_males_avg_vote           0
# imdb_males_votes              0
# mc_av                         0
# mc_no                         0
# ma_av                         0
# ma_no                         0
# dtype: int64

# %%
db_fix = db_fix.rename(columns={'Year_x':'Year','Worldwide_Lifetime_Gross':'All_time_gross','tomatometer_rating':'tom_cri_vote',
                               'tomatometer_count':'tom_cri_num','tomato_audience_rating':'tom_aud_vote','tomato_audience_vote_count':'tom_aud_num',
                               'imdb_avg_vote':'imdb_vote','imdb_total_votes':'imdb_num','imdb_us_voters_rating':'imdb_us_vote',
                               'imdb_us_voters_votes':'imdb_us_num','imdb_non_us_voters_rating':'imdb_nus_vote','imdb_non_us_voters_votes':'imdb_nus_num',
                               'imdb_females_avg_vote':'imdb_fem_vote','imdb_females_votes':'imdb_fem_num','imdb_males_avg_vote':'imdb_mal_vote',
                               'imdb_males_votes':'imdb_mal_num','mc_av':'met_cri_vote','mc_no':'met_cri_num','ma_av':'met_aud_vote','ma_no':'met_aud_num'})

# %%
db_fix.columns
# Out:
# Index(['Title', 'Alternative Title', 'director', 'Year', 'date_published',
#        'All_time_gross', 'Domestic_Lifetime_Gross', 'Foreign_Lifetime_Gross',
#        'tom_cri_vote', 'tom_cri_num', 'tom_aud_vote', 'tom_aud_num',
#        'imdb_vote', 'imdb_num', 'imdb_us_vote', 'imdb_us_num', 'imdb_nus_vote',
#        'imdb_nus_num', 'imdb_fem_vote', 'imdb_fem_num', 'imdb_mal_vote',
#        'imdb_mal_num', 'met_cri_vote', 'met_cri_num', 'met_aud_vote',
#        'met_aud_num'],
#       dtype='object')

# %%
new_col=['Title', 'Alternative Title', 'director', 'Year', 'date_published',
       'All_time_gross', 'Domestic_Lifetime_Gross', 'Foreign_Lifetime_Gross',
       'tom_cri_vote', 'tom_cri_num', 'tom_aud_vote', 'tom_aud_num','met_cri_vote', 'met_cri_num', 'met_aud_vote', 'met_aud_num', 'imdb_vote',
       'imdb_num', 'imdb_us_vote', 'imdb_us_num', 'imdb_nus_vote', 'imdb_nus_num',
       'imdb_fem_vote', 'imdb_fem_num', 'imdb_mal_vote', 'imdb_mal_num']
db_fix = db_fix[new_col]

# %%
db_fix.head()
# Out:
#                                          Title  \
# 0                      The Mountain Between Us
# 1                                      Rampage
# 2  Valerian and the City of a Thousand Planets
# 3                                 The Forgiven
# 4                       Spider-Man: Homecoming
#
#                                    Alternative Title        director  Year  \
# 0                               Il domani tra di noi  Hany Abu-Assad  2017
# 1                             Rampage: Furia animale     Brad Peyton  2018
# 2  Valerian e la cittÀ_À__À_À__ dei mille pia...      Luc Besson  2017
# 3             Condannato a combattere - The Forgiven   Roland JoffÍ©  2017
# 4                             Spider-Man: Homecoming       Jon Watts  2017
#
#   date_published  All_time_gross  Domestic_Lifetime_Gross  \
# 0     2017-11-23        62832209                 30348555
# 1     2018-04-12       428028233                101028233
# 2     2017-09-21       225973340                 41189488
# 3     2018-03-09           42213                        0
# 4     2017-07-06       880166924                334201140
#
#    Foreign_Lifetime_Gross  tom_cri_vote  tom_cri_num  ...  imdb_vote  \
# 0                32483654            38          171  ...         64
# 1               327000000            51          275  ...         61
# 2               184783852            48          294  ...         65
# 3                   42213            52           23  ...         59
# 4               545965784            92          390  ...         74
#
#    imdb_num  imdb_us_vote  imdb_us_num  imdb_nus_vote  imdb_nus_num  \
# 0     64703            64         7520             63         27997
# 1    137865            61        17163             60         54731
# 2    157560            63        17690             64         69287
# 3      1857            59          344             58           746
# 4    494060            76        57625             73        172006
#
#    imdb_fem_vote  imdb_fem_num  imdb_mal_vote  imdb_mal_num
# 0             67         13462             63         35093
# 1             64         13702             60         84286
# 2             64         18118             65         99701
# 3             61           257             58          1122
# 4             76         49874             74        282567
#
# [5 rows x 26 columns]

# %%
db_fix['met_cri_vote'] = db_fix['met_cri_vote'].astype('int')
db_fix['met_cri_num'] = db_fix['met_cri_num'].astype('int')
db_fix['met_aud_vote'] = db_fix['met_aud_vote'].astype('int')
db_fix['met_aud_num'] = db_fix['met_aud_num'].astype('int')

# %%
db_fix.to_csv('/Users/Amin/Documents/GitHub/Movie_boxoffice_reviews/data/processed/movie_db_fianl1.csv')
